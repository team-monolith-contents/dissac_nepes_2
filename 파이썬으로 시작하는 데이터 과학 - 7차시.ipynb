# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #3c763d; background-color: #dff0d8; border-color: #d6e9c6; font-weight: bold;">
#     <br><br>
#     <div style="font-weight: bold; font-size: 40px">파이썬으로 시작하는 데이터 과학</div>
#     <div style="font-weight: bold; font-size: 20px">(7) 프로젝트</div>
#     <hr style="width:80%;text-align:left;margin-left:0;border:0.5px solid green">
#     <br>
#     &#x2022; 데이터를 탐색하고 필요한 데이터를 찾을 수 있다.  <br>
#     &#x2022; 데이터를 분석할 수 있다. <br>
#     &#x2022; 데이터를 시각화할 수 있다.<br>
# </div>

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #3c763d; border-color: #d6e9c6; font-weight: bold;">
# <h2 style='font-weight: bold'>0. 프로젝트 개요</h2>
# </div>

# %% [markdown]
# ### **데이터를 통해 장사의 신이 되어보자**
#
# 코들이가 재미삼아 산 로또가 1등에 당첨되었습니다!!!!
# 당첨금은 약 23억원 이었습니다.
# 코들이는 이 당첨금으로는 평생 먹고 살기 어렵다는 것을 깨달았습니다.
# 그래서 코들이는 당첨금으로 가게를 열어 더 많은 돈을 벌려고 합니다.
# 하지만 코들이는 장사에 대해 생각해 본 적도 없고 아는 것도 없습니다.
# 그러다 문득 학교 수업시간에 데이터 분석을 배운 것이 생각났습니다.
# 코들이는 데이터 분석 수업을 같이 들은 여러분과 함께 어떤 가게를 하면 장사가 잘 될지 함께 고민하려 합니다.
#
# 코들이를 도와 어떤 가게를 어디에 차리면 좋을지 데이터를 분석해봅시다.

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #3c763d; border-color: #d6e9c6; font-weight: bold;">
# <h2 style='font-weight: bold'>1. 데이터 탐색하기</h2>
# </div>

# %% [markdown]
# 데이터를 분석하는 데에 가장 중요한 것 중 하나는 적절한 데이터를 선정하는 것입니다.
# 최근에는 여러 기업이나 정부기관에서 데이터를 공개하고 있기 때문에 데이터를 선정할 수 있는 폭이 넓습니다.
# 특히 [공공데이터포털](https://www.data.go.kr/index.do)에서는 정부기관에서 제공하는 다양한 데이터를 사용할 수 있습니다.
# 또는 [kaggle(캐글)](https://www.kaggle.com/datasets)이라는 온라인 커뮤니티에서 다양한 데이터를 활용할 수도 있습니다.
#
# > `read_csv()` 함수를 사용해 데이터를 읽어오고 `head()`, `trail()`, `info()` 함수등을 이용해 데이터를 관찰할 수 있습니다.
# >
# > 여러분이 쓸만한 데이터가 있나요??

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #8a6d3b;  border-color: #faebcc; font-weight: bold;">
#     <div style="font-weight: bold; font-size: 20px">✏️ 생각해보기</div>
#     <br>
# 어떤 데이터를 분석하면 좋을까요?  <br>
# 여러분의 생각을 아래의 셀에 적어주세요.
# </div>

# %%
 👉

# %% [markdown]
# 이번 프로젝트에서는 한옥체험업 자료와 한식 레스토랑 자료를 분석해보고자 합니다.
#
# 한옥 체험업을 하는 곳은 외국인 관광객이 많을 것이고, 외국인 관광객의 특성상 한식을 먹는 것을 선호할 것입니다.
# 따라서 한옥체험업을 가장 많이하면서도 주변에 한식 식당이 적은 곳에 한식 레스토랑을 차린다면 장사에 성공할 수 있을 것입니다.

# %%
import pandas as pd

hanok = pd.read_csv('https://tmn-bucket-materials-all.s3.ap-northeast-2.amazonaws.com/data/%ED%95%9C%EC%98%A5%EC%B2%B4%ED%97%98%EC%97%85.csv')
print(hanok.info())
hanok.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2152 entries, 0 to 2151
# Data columns (total 64 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   번호           2152 non-null   int64
#  1   개방서비스명       2152 non-null   object
#  2   개방서비스아이디     2152 non-null   object
#  3   개방자치단체코드     2152 non-null   int64
#  4   관리번호         2152 non-null   object
#  5   인허가일자        2152 non-null   int64
#  6   인허가취소일자      3 non-null      float64
#  7   영업상태구분코드     2152 non-null   int64
#  8   영업상태명        2152 non-null   object
#  9   상세영업상태코드     2152 non-null   int64
#  10  상세영업상태명      2152 non-null   object
#  11  폐업일자         411 non-null    float64
#  12  휴업시작일자       11 non-null     float64
#  13  휴업종료일자       411 non-null    float64
#  14  재개업일자        0 non-null      float64
#  15  소재지전화        534 non-null    object
#  16  소재지면적        0 non-null      float64
#  17  소재지우편번호      894 non-null    float64
#  18  소재지전체주소      2152 non-null   object
#  19  도로명전체주소      1667 non-null   object
#  20  도로명우편번호      1418 non-null   float64
#  21  사업장명         2152 non-null   object
#  22  최종수정시점       2152 non-null   int64
#  23  데이터갱신구분      2152 non-null   object
#  24  데이터갱신일자      2152 non-null   object
#  25  업태구분명        0 non-null      float64
#  26  좌표정보(x)      2130 non-null   float64
#  27  좌표정보(y)      2130 non-null   float64
#  28  문화체육업종명      2147 non-null   object
#  29  문화사업자구분명     0 non-null      float64
#  30  지역구분명        864 non-null    object
#  31  총층수          1341 non-null   float64
#  32  주변환경명        672 non-null    object
#  33  제작취급품목내용     0 non-null      float64
#  34  보험기관명        59 non-null     object
#  35  건물용도명        1099 non-null   object
#  36  지상층수         1290 non-null   float64
#  37  지하층수         671 non-null    float64
#  38  객실수          551 non-null    float64
#  39  건축연면적        539 non-null    float64
#  40  영문상호명        258 non-null    object
#  41  영문상호주소       228 non-null    object
#  42  선박총톤수        511 non-null    float64
#  43  선박척수         511 non-null    float64
#  44  선박제원         0 non-null      float64
#  45  무대면적         511 non-null    float64
#  46  좌석수          511 non-null    float64
#  47  기념품종류        0 non-null      float64
#  48  회의실별동시수용인원   511 non-null    float64
#  49  시설면적         1489 non-null   float64
#  50  놀이기구수내역      0 non-null      float64
#  51  놀이시설수        511 non-null    float64
#  52  방송시설유무       0 non-null      float64
#  53  발전시설유무       0 non-null      float64
#  54  의무실유무        0 non-null      float64
#  55  안내소유무        0 non-null      float64
#  56  기획여행보험시작일자   0 non-null      float64
#  57  기획여행보험종료일자   0 non-null      float64
#  58  자본금          820 non-null    float64
#  59  보험시작일자       0 non-null      float64
#  60  보험종료일자       0 non-null      float64
#  61  부대시설내역       0 non-null      float64
#  62  시설규모         1489 non-null   float64
#  63  Unnamed: 63  0 non-null      float64
# dtypes: float64(40), int64(6), object(18)
# memory usage: 1.1+ MB
# None
#    번호 개방서비스명    개방서비스아이디  개방자치단체코드                  관리번호     인허가일자  인허가취소일자  \
# 0   1  한옥체험업  03_11_06_P   3470000  CDFI3261132013000001  20130717      NaN
# 1   2  한옥체험업  03_11_06_P   3480000  CDFI3261132010000001  20100811      NaN
# 2   3  한옥체험업  03_11_06_P   3480000  CDFI3261132010000002  20100811      NaN
# 3   4  한옥체험업  03_11_06_P   3480000  CDFI3261132011000001  20110923      NaN
# 4   5  한옥체험업  03_11_06_P   3480000  CDFI3261132015000001  20150210      NaN
# 5   6  한옥체험업  03_11_06_P   5210000  CDFI3261132010000002  20100510      NaN
# 6   7  한옥체험업  03_11_06_P   5230000  CDFI3261132015000002  20150702      NaN
# 7   8  한옥체험업  03_11_06_P   5230000  CDFI3261132015000003  20151014      NaN
# 8   9  한옥체험업  03_11_06_P   5230000  CDFI3261132015000005  20151022      NaN
# 9  10  한옥체험업  03_11_06_P   5230000  CDFI3261132015000006  20151218      NaN
#
#    영업상태구분코드  영업상태명  상세영업상태코드  ... 의무실유무  안내소유무  기획여행보험시작일자  기획여행보험종료일자  \
# 0         1  영업/정상        13  ...   NaN    NaN         NaN         NaN
# 1         1  영업/정상        13  ...   NaN    NaN         NaN         NaN
# 2         1  영업/정상        13  ...   NaN    NaN         NaN         NaN
# 3         1  영업/정상        13  ...   NaN    NaN         NaN         NaN
# 4         1  영업/정상        13  ...   NaN    NaN         NaN         NaN
# 5         1  영업/정상        13  ...   NaN    NaN         NaN         NaN
# 6         1  영업/정상        13  ...   NaN    NaN         NaN         NaN
# 7         1  영업/정상        13  ...   NaN    NaN         NaN         NaN
# 8         1  영업/정상        13  ...   NaN    NaN         NaN         NaN
# 9         1  영업/정상        13  ...   NaN    NaN         NaN         NaN
#
#           자본금 보험시작일자  보험종료일자  부대시설내역   시설규모 Unnamed: 63
# 0         NaN    NaN     NaN     NaN    NaN         NaN
# 1         0.0    NaN     NaN     NaN  357.0         NaN
# 2         0.0    NaN     NaN     NaN  282.0         NaN
# 3  80800000.0    NaN     NaN     NaN    0.0         NaN
# 4         0.0    NaN     NaN     NaN    0.0         NaN
# 5         NaN    NaN     NaN     NaN    NaN         NaN
# 6         NaN    NaN     NaN     NaN    NaN         NaN
# 7         NaN    NaN     NaN     NaN  105.0         NaN
# 8         NaN    NaN     NaN     NaN  257.0         NaN
# 9         NaN    NaN     NaN     NaN    NaN         NaN
#
# [10 rows x 64 columns]

# %%
restaurant = pd.read_csv('https://tmn-bucket-materials-all.s3.ap-northeast-2.amazonaws.com/data/%EC%9D%BC%EB%B0%98%EC%9D%8C%EC%8B%9D%EC%A0%90_3.csv')
print(restaurant.info())
restaurant.head(10)
# Out:
# /tmp/ipykernel_714/2459733207.py:1: DtypeWarning: Columns (11,39,44,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   restaurant = pd.read_csv('https://tmn-bucket-materials-all.s3.ap-northeast-2.amazonaws.com/data/%EC%9D%BC%EB%B0%98%EC%9D%8C%EC%8B%9D%EC%A0%90_3.csv')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 511915 entries, 0 to 511914
# Data columns (total 48 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   번호           511915 non-null  int64
#  1   개방서비스명       511915 non-null  object
#  2   개방서비스아이디     511915 non-null  object
#  3   개방자치단체코드     511915 non-null  int64
#  4   관리번호         511915 non-null  object
#  5   인허가일자        511852 non-null  object
#  6   인허가취소일자      0 non-null       float64
#  7   영업상태구분코드     511915 non-null  int64
#  8   영업상태명        511915 non-null  object
#  9   상세영업상태코드     511915 non-null  int64
#  10  상세영업상태명      511915 non-null  object
#  11  폐업일자         334583 non-null  object
#  12  휴업시작일자       0 non-null       float64
#  13  휴업종료일자       0 non-null       float64
#  14  재개업일자        0 non-null       float64
#  15  소재지전화        335575 non-null  object
#  16  소재지면적        481290 non-null  float64
#  17  소재지우편번호      501802 non-null  object
#  18  소재지전체주소      510758 non-null  object
#  19  도로명전체주소      308507 non-null  object
#  20  도로명우편번호      302827 non-null  float64
#  21  사업장명         511915 non-null  object
#  22  최종수정시점       511915 non-null  object
#  23  데이터갱신구분      511915 non-null  object
#  24  데이터갱신일자      511915 non-null  object
#  25  업태구분명        511861 non-null  object
#  26  좌표정보(x)      472494 non-null  float64
#  27  좌표정보(y)      472494 non-null  float64
#  28  위생업태명        511861 non-null  object
#  29  남성종사자수       318571 non-null  float64
#  30  여성종사자수       322015 non-null  float64
#  31  영업장주변구분명     208744 non-null  object
#  32  등급구분명        78314 non-null   object
#  33  급수시설구분명      356846 non-null  object
#  34  총직원수         89027 non-null   float64
#  35  본사직원수        105119 non-null  float64
#  36  공장사무직직원수     105118 non-null  float64
#  37  공장판매직직원수     105118 non-null  float64
#  38  공장생산직직원수     105118 non-null  float64
#  39  건물소유구분명      2 non-null       object
#  40  보증액          105119 non-null  float64
#  41  월세액          105119 non-null  float64
#  42  다중이용업소여부     511915 non-null  object
#  43  시설총규모        511915 non-null  float64
#  44  전통업소지정번호     1595 non-null    object
#  45  전통업소주된음식     310 non-null     object
#  46  홈페이지         0 non-null       float64
#  47  Unnamed: 47  0 non-null       float64
# dtypes: float64(20), int64(4), object(24)
# memory usage: 187.5+ MB
# None
#         번호 개방서비스명    개방서비스아이디  개방자치단체코드                    관리번호       인허가일자  \
# 0  1023831  일반음식점  07_24_04_P   6510000  6510000-101-1998-00711  1998-12-21
# 1  1023832  일반음식점  07_24_04_P   6510000  6510000-101-1981-00059  1981-11-13
# 2  1023833  일반음식점  07_24_04_P   6510000  6510000-101-1981-00058  1981-11-11
# 3  1023834  일반음식점  07_24_04_P   6510000  6510000-101-1981-00057  1981-10-30
# 4  1023835  일반음식점  07_24_04_P   6510000  6510000-101-1981-00055  1981-10-16
# 5  1023836  일반음식점  07_24_04_P   6510000  6510000-101-1981-00056  1981-10-16
# 6  1023837  일반음식점  07_24_04_P   6510000  6510000-101-1981-00054  1981-10-08
# 7  1023838  일반음식점  07_24_04_P   6510000  6510000-101-1981-00053  1981-09-28
# 8  1023839  일반음식점  07_24_04_P   6510000  6510000-101-2001-00120  2001-03-08
# 9  1023840  일반음식점  07_24_04_P   6510000  6510000-101-1998-00368  1998-06-19
#
#    인허가취소일자  영업상태구분코드 영업상태명  상세영업상태코드  ... 공장생산직직원수 건물소유구분명  보증액  월세액  \
# 0      NaN         3    폐업         2  ...      NaN     NaN  NaN  NaN
# 1      NaN         3    폐업         2  ...      NaN     NaN  NaN  NaN
# 2      NaN         3    폐업         2  ...      NaN     NaN  NaN  NaN
# 3      NaN         3    폐업         2  ...      NaN     NaN  NaN  NaN
# 4      NaN         3    폐업         2  ...      NaN     NaN  NaN  NaN
# 5      NaN         3    폐업         2  ...      NaN     NaN  NaN  NaN
# 6      NaN         3    폐업         2  ...      NaN     NaN  NaN  NaN
# 7      NaN         3    폐업         2  ...      NaN     NaN  NaN  NaN
# 8      NaN         3    폐업         2  ...      NaN     NaN  NaN  NaN
# 9      NaN         3    폐업         2  ...      NaN     NaN  NaN  NaN
#
#    다중이용업소여부   시설총규모  전통업소지정번호 전통업소주된음식 홈페이지 Unnamed: 47
# 0         N   17.70       NaN      NaN  NaN         NaN
# 1         N   33.00       NaN      NaN  NaN         NaN
# 2         N   35.00       NaN      NaN  NaN         NaN
# 3         N   49.70       NaN      NaN  NaN         NaN
# 4         N   39.90       NaN      NaN  NaN         NaN
# 5         N  165.00       NaN      NaN  NaN         NaN
# 6         N   21.00       NaN      NaN  NaN         NaN
# 7         N  112.00       NaN      NaN  NaN         NaN
# 8         N   61.00       NaN      NaN  NaN         NaN
# 9         N   49.44       NaN      NaN  NaN         NaN
#
# [10 rows x 48 columns]

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #3c763d; border-color: #d6e9c6; font-weight: bold;">
# <h2 style='font-weight: bold'>2. 데이터 분석하기</h2>
# </div>

# %% [markdown]
# 데이터를 선정한 뒤에는 아이디어에 맞게 데이터를 분석해야 합니다.
# 데이터를 분석하기 위해서는 앞선 시간에서 배웠던 pandas의 여러가지 함수를 사용할 수 있습니다.

# %% [markdown]
# **한옥체험업 데이터**

# %%
hanok = hanok[['영업상태명','도로명전체주소']]

# %%
print(len(hanok))
hanok = hanok[hanok['영업상태명'] == '영업/정상']
print(len(hanok))
# Out:
# 2152
# 1734

# %%
print(len(hanok))
hanok = hanok.dropna()
print(len(hanok))
# Out:
# 1734
# 1319

# %%
hanok['행정구역'] = hanok['도로명전체주소'].apply(lambda x :' '.join(x.split()[:2]))
hanok
# Out:
#       영업상태명                      도로명전체주소       행정구역
# 0     영업/정상       대구광역시 달서구 새방로 21 (용산동)  대구광역시 달서구
# 1     영업/정상        대구광역시 달성군 하빈면 육신사길 55  대구광역시 달성군
# 2     영업/정상        대구광역시 달성군 하빈면 육신사길 64  대구광역시 달성군
# 3     영업/정상   대구광역시 달성군 구지면 구지서로60길 41-5  대구광역시 달성군
# 4     영업/정상        대구광역시 달성군 현풍읍 지동1길 43  대구광역시 달성군
# ...     ...                          ...        ...
# 1729  영업/정상     경상북도 안동시 중들3길 20-7 (용상동)   경상북도 안동시
# 1730  영업/정상       강원도 강릉시 임영로 196-6 (교동)    강원도 강릉시
# 1731  영업/정상   대구광역시 남구 이천로28길 27-4 (이천동)   대구광역시 남구
# 1732  영업/정상        충청남도 보령시 절터길 41 (요암동)   충청남도 보령시
# 1733  영업/정상  경상북도 경주시 첨성로99번길 30-6 (황남동)   경상북도 경주시
#
# [1319 rows x 3 columns]

# %%
hanok = hanok.groupby('행정구역').count()['도로명전체주소']
hanok
# Out:
# 행정구역
# 강원도 강릉시     23
# 강원도 고성군      1
# 강원도 동해시      4
# 강원도 삼척시      1
# 강원도 양양군      2
#             ..
# 충청북도 제천시     1
# 충청북도 증평군     1
# 충청북도 청주시     8
# 충청북도 충주시     1
# 황룡면 433      1
# Name: 도로명전체주소, Length: 146, dtype: int64

# %%
print(hanok.idxmax(), hanok.max())
# Out:
# 전라북도 전주시 194

# %% [markdown]
# **식당 데이터**

# %%
restaurant = restaurant[['영업상태명','도로명전체주소','업태구분명']]
restaurant
# Out:
#         영업상태명                          도로명전체주소     업태구분명
# 0          폐업                              NaN        한식
# 1          폐업                              NaN        한식
# 2          폐업      제주특별자치도 제주시 중앙로 46-1 (일도일동)       중국식
# 3          폐업                              NaN        한식
# 4          폐업                              NaN        한식
# ...       ...                              ...       ...
# 511910  영업/정상  경기도 남양주시 오남읍 진건오남로577번길 10 (1층)        까페
# 511911  영업/정상          경기도 남양주시 화도읍 녹촌로 87, 1층     호프/통닭
# 511912  영업/정상   경기도 김포시 김포한강9로12번길 97-22 (구래동)        횟집
# 511913  영업/정상    경기도 김포시 양촌읍 김포대로1759번길 134-37        한식
# 511914  영업/정상    경기도 안성시 공도읍 대림동산길 7 ((X5-X6))  식육(숯불구이)
#
# [511915 rows x 3 columns]

# %%
restaurant = restaurant[restaurant['업태구분명'] == '한식']
restaurant
# Out:
#         영업상태명                               도로명전체주소 업태구분명
# 0          폐업                                   NaN    한식
# 1          폐업                                   NaN    한식
# 3          폐업                                   NaN    한식
# 4          폐업                                   NaN    한식
# 5          폐업                                   NaN    한식
# ...       ...                                   ...   ...
# 511899  영업/정상            경기도 동두천시 중앙로 293, 2층 (생연동)    한식
# 511900  영업/정상             경기도 동두천시 정장로 50, 1층 (생연동)    한식
# 511902  영업/정상            경기도 광주시 경안로 14-7, 1층 (경안동)    한식
# 511905  영업/정상  경기도 고양시 덕양구 충장로 134 (행신동, 아이프라자115호)    한식
# 511913  영업/정상         경기도 김포시 양촌읍 김포대로1759번길 134-37    한식
#
# [244517 rows x 3 columns]

# %%
restaurant['영업상태명'].unique()
# Out:
# array(['폐업', '영업/정상'], dtype=object)

# %%
restaurant = restaurant[restaurant['영업상태명'] == '영업/정상']
restaurant
# Out:
#         영업상태명                                        도로명전체주소 업태구분명
# 334587  영업/정상          경기도 성남시 수정구 산성대로295번길 9, 1(일부)층 (신흥동)    한식
# 334589  영업/정상                    경기도 안성시 대덕면 중앙대학로 116-1, 2층    한식
# 334590  영업/정상                 서울특별시 영등포구 도신로33길 11, 1층 (도림동)    한식
# 334593  영업/정상                   경상남도 양산시 물금읍 백호2길 23-9, 1층일부    한식
# 334597  영업/정상  서울특별시 금천구 가산로5길 15, 가산더블레스 1층 101, 102호 (가산동)    한식
# ...       ...                                            ...   ...
# 511899  영업/정상                     경기도 동두천시 중앙로 293, 2층 (생연동)    한식
# 511900  영업/정상                      경기도 동두천시 정장로 50, 1층 (생연동)    한식
# 511902  영업/정상                     경기도 광주시 경안로 14-7, 1층 (경안동)    한식
# 511905  영업/정상           경기도 고양시 덕양구 충장로 134 (행신동, 아이프라자115호)    한식
# 511913  영업/정상                  경기도 김포시 양촌읍 김포대로1759번길 134-37    한식
#
# [77840 rows x 3 columns]

# %%
restaurant = restaurant.dropna()
restaurant
# Out:
#         영업상태명                                        도로명전체주소 업태구분명
# 334587  영업/정상          경기도 성남시 수정구 산성대로295번길 9, 1(일부)층 (신흥동)    한식
# 334589  영업/정상                    경기도 안성시 대덕면 중앙대학로 116-1, 2층    한식
# 334590  영업/정상                 서울특별시 영등포구 도신로33길 11, 1층 (도림동)    한식
# 334593  영업/정상                   경상남도 양산시 물금읍 백호2길 23-9, 1층일부    한식
# 334597  영업/정상  서울특별시 금천구 가산로5길 15, 가산더블레스 1층 101, 102호 (가산동)    한식
# ...       ...                                            ...   ...
# 511899  영업/정상                     경기도 동두천시 중앙로 293, 2층 (생연동)    한식
# 511900  영업/정상                      경기도 동두천시 정장로 50, 1층 (생연동)    한식
# 511902  영업/정상                     경기도 광주시 경안로 14-7, 1층 (경안동)    한식
# 511905  영업/정상           경기도 고양시 덕양구 충장로 134 (행신동, 아이프라자115호)    한식
# 511913  영업/정상                  경기도 김포시 양촌읍 김포대로1759번길 134-37    한식
#
# [76980 rows x 3 columns]

# %%
restaurant['행정구역'] = restaurant['도로명전체주소'].apply(lambda x :' '.join(x.split()[:2]))
restaurant
# Out:
# /tmp/ipykernel_714/767084600.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   restaurant['행정구역'] = restaurant['도로명전체주소'].apply(lambda x :' '.join(x.split()[:2]))
#         영업상태명                                        도로명전체주소 업태구분명        행정구역
# 334587  영업/정상          경기도 성남시 수정구 산성대로295번길 9, 1(일부)층 (신흥동)    한식     경기도 성남시
# 334589  영업/정상                    경기도 안성시 대덕면 중앙대학로 116-1, 2층    한식     경기도 안성시
# 334590  영업/정상                 서울특별시 영등포구 도신로33길 11, 1층 (도림동)    한식  서울특별시 영등포구
# 334593  영업/정상                   경상남도 양산시 물금읍 백호2길 23-9, 1층일부    한식    경상남도 양산시
# 334597  영업/정상  서울특별시 금천구 가산로5길 15, 가산더블레스 1층 101, 102호 (가산동)    한식   서울특별시 금천구
# ...       ...                                            ...   ...         ...
# 511899  영업/정상                     경기도 동두천시 중앙로 293, 2층 (생연동)    한식    경기도 동두천시
# 511900  영업/정상                      경기도 동두천시 정장로 50, 1층 (생연동)    한식    경기도 동두천시
# 511902  영업/정상                     경기도 광주시 경안로 14-7, 1층 (경안동)    한식     경기도 광주시
# 511905  영업/정상           경기도 고양시 덕양구 충장로 134 (행신동, 아이프라자115호)    한식     경기도 고양시
# 511913  영업/정상                  경기도 김포시 양촌읍 김포대로1759번길 134-37    한식     경기도 김포시
#
# [76980 rows x 4 columns]

# %%
restaurant = restaurant.groupby('행정구역').count()['도로명전체주소']
restaurant
# Out:
# 행정구역
# 강원도 강릉시      711
# 강원도 고성군       35
# 강원도 동해시       77
# 강원도 삼척시       35
# 강원도 속초시      166
#             ...
# 충청북도 제천시     958
# 충청북도 증평군     294
# 충청북도 진천군     762
# 충청북도 청주시    4536
# 충청북도 충주시    1615
# Name: 도로명전체주소, Length: 302, dtype: int64

# %%
print(restaurant.idxmax(), restaurant.max())
# Out:
# 충청북도 청주시 4536

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #8a6d3b;  border-color: #faebcc; font-weight: bold;">
#     <div style="font-weight: bold; font-size: 20px">✏️ 생각해보기</div>
#     <br>
# 데이터에 어떠한 규칙이 보이나요?<br>
# 데이터를 보고 어떤 사실을 알 수 있나요?
# </div>

# %%
 👉

# %% [markdown]
# 코들이는 다음의 정보들을 찾았습니다.
# - 한옥체험업을 하는 업체가 가장 많은 곳은 전라북도 전주시이다.
# - 한식 식당이 가장 많은 곳은 충청북도 청주시이다.

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #3c763d; border-color: #d6e9c6; font-weight: bold;">
# <h2 style='font-weight: bold'>3. 데이터 시각화</h2>
# </div>

# %% [markdown]
# 데이터를 시각화하는 것도 데이터를 분석하는데 많이 사용하는 방법입니다.
# 데이터를 시각화함으로써 기존에 보이지 않던 규칙이나 패턴이 보이기도 합니다.
# 또한 데이터를 시각화하면 내가 보여주고 싶은 정보를 다른 사람들에게 더욱 효과적으로 보여줄 수 있습니다.

# %% [markdown]
# > 데이터를 적절한 그래프로 시각화해봅시다.
# > 데이터를 시각화하기 위해서는 앞선 시간에 배웠던 matplotlib의 여러가지 함수들을 사용할 수 있습니다.

# %%
new_df = pd.DataFrame()
new_df['한옥'] = hanok
new_df['식당'] = restaurant
new_df
# Out:
#           한옥      식당
# 행정구역
# 강원도 강릉시   23   711.0
# 강원도 고성군    1    35.0
# 강원도 동해시    4    77.0
# 강원도 삼척시    1    35.0
# 강원도 양양군    2    37.0
# ...       ..     ...
# 충청북도 제천시   1   958.0
# 충청북도 증평군   1   294.0
# 충청북도 청주시   8  4536.0
# 충청북도 충주시   1  1615.0
# 황룡면 433    1     NaN
#
# [146 rows x 2 columns]

# %%
new_df = new_df.fillna(0)
new_df
# Out:
#           한옥      식당
# 행정구역
# 강원도 강릉시   23   711.0
# 강원도 고성군    1    35.0
# 강원도 동해시    4    77.0
# 강원도 삼척시    1    35.0
# 강원도 양양군    2    37.0
# ...       ..     ...
# 충청북도 제천시   1   958.0
# 충청북도 증평군   1   294.0
# 충청북도 청주시   8  4536.0
# 충청북도 충주시   1  1615.0
# 황룡면 433    1     0.0
#
# [146 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

plt.scatter(new_df['한옥'],new_df['식당'])
plt.title('한옥 vs 식당')
plt.xlabel('한옥')
plt.ylabel('식당')
plt.grid()
plt.show()

# %%
plt.scatter(new_df['한옥'],new_df['식당'])
plt.title('한옥 vs 식당')
plt.xlabel('한옥')
plt.ylabel('식당')
plt.grid()

for row in range(len(new_df)):
    row = new_df.iloc[row]
    plt.text(row['한옥'], row['식당'], row.name, size=5)

plt.show()

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #8a6d3b;  border-color: #faebcc; font-weight: bold;">
#     <div style="font-weight: bold; font-size: 20px">✏️ 생각해보기</div>
#     <br>
# 시각화를 통해 새로운 패턴을 발견했나요?<br>
# 어떠한 정보를 다른 사람들에게 보여주고 싶나요?
# </div>

# %%
 👉

# %% [markdown]
# 코들이는 이 프로젝트를 통해 전주시, 안동시에 식당을 차리기로 마음을 먹게 되었습니다.

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #3c763d; border-color: #d6e9c6; font-weight: bold;">
# <h2 style='font-weight: bold'>4. 마무리</h2>
# </div>

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #8a6d3b;  border-color: #faebcc; font-weight: bold;">
#     <div style="font-weight: bold; font-size: 20px">✏️ 생각해보기</div>
#     <br>
# 이번 프로젝트를 통해 무엇을 알게되었나요??  <br>
# 이번 프로젝트를 진행하면서 아쉬웠던 점은 무엇인가요??  <br>
# 이번 프로젝트 이후에 더 탐구해보고 싶은 것이 있나요??  <br>
# </div>

# %%
 👉
